# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import requests
from bs4 import BeautifulSoup

BASE_URL = 'https://www.b9.com.br'
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36'
}

def get_soup(url):
    response = requests.get(url, headers=HEADERS)
    response.raise_for_status()
    return BeautifulSoup(response.text, 'html.parser')

def extract_references(post_url):
    soup = get_soup(post_url)
    references_section = soup.find('p', text=lambda x: x and 'REFERÊNCIAS' in x)
    if not references_section:
        return []
    
    references = []
    for sibling in references_section.find_next_siblings():
        if sibling.get_text(strip=True) == '========':
            break
        references.append(sibling.get_text(strip=True))
    
    return references

# Test the function
post_url = 'https://www.b9.com.br/shows/naruhodo/naruhodo-418-o-que-e-a-birra/?highlight=naruhodo'
references = extract_references(post_url)
print(references)
# Out:
# ['Assessment, management, and prevention of childhood temper tantrumshttps://journals.lww.com/jaanp/abstract/2012/10000/assessment,_management,_and_prevention_of.2.aspx', 'Temper Tantrums in Young Children: 2. Tantrum Duration and Temporal Organizationhttps://journals.lww.com/jrnldbp/fulltext/2003/06000/temper_tantrums_in_young_children__2__tantrum.3.aspx?casa_token=XT0dxgcDQJMAAAAA:KXBH6vF25IZT4vBlzGF3SysfHTm6XlWlcOFuAp_pcIfqXl2s_-yU_6pvKirSKoFbV8Y7jLlaqqq8zdLWV0W4NmaXTw', 'Temper Tantrums in Young Children: 1. Behavioral Compositionhttps://journals.lww.com/jrnldbp/fulltext/2003/06000/temper_tantrums_in_young_children__1__behavioral.2.aspx?casa_token=86hhrSeXMh0AAAAA:ZEF3NP81tjsathb5NVrGbcc08KdVqBjLNRBGr4pwZAkkRZszvPoUyZuTzdnwyRjirZ_ejI11i9YDHUVa3uNK1EAEOg', 'Meltdown/Tantrum Detection System for Individuals with Autism Spectrum Disorderhttps://www.tandfonline.com/doi/full/10.1080/08839514.2021.1991115', 'Developmental pathways from preschool temper tantrums to later psychopathologyhttps://www.cambridge.org/core/journals/development-and-psychopathology/article/abs/developmental-pathways-from-preschool-temper-tantrums-to-later-psychopathology/6668E79FAD80D21A26E3A2E8FB10D322', 'Emotional Development in Early Infancyhttps://www.jstor.org/stable/1125359?origin=crossref', 'Screaming, Yelling, Whining and Crying: Categorical and intensity differences in Vocal Expressions of Anger and Sadness in Children’s Tantrumshttps://www.ncbi.nlm.nih.gov/pmc/articles/PMC3192404/', 'Young Children’s Understanding of the Causes of Anger and Sadnesshttps://www.jstor.org/stable/1131944?origin=crossref', 'A systematic review of the effects of motor interventions to improve motor, cognitive, and/or social functioning in people with severe or profound intellectual disabilitieshttps://www.sciencedirect.com/science/article/pii/S0891422214002066?casa_token=gb8j_4rhocMAAAAA:IFAnWFT5NKwINV1Ty0eWBu55ZZS0eQ3zS5_Ud1INCjKDLyZqvV4KdP3rh00_NzwHfusKkdEANQ', 'Emotional self-regulation in preschoolers: The interplay of child approach reactivity, parenting, and control capacities.https://psycnet.apa.org/doiLanding?doi=10.1037%2F0012-1649.42.1.84', 'Cognitive systems for revenge and forgivenesshttps://www.cambridge.org/core/journals/behavioral-and-brain-sciences/article/abs/cognitive-systems-for-revenge-and-forgiveness/3EE59DAB2918E5E72105B14FB589150E', 'The role of loudness in vocal intimidation.https://psycnet.apa.org/record/2024-28586-001', 'Understanding Phasic Irritability: Anger and Distress in Children’s Temper Outburstshttps://link.springer.com/article/10.1007/s10578-021-01126-5', 'A Cross-Sectional Study of Onset, Cessation, Frequency, and Duration of Children’s Temper Tantrums in a Nonclinical Samplehttps://journals.sagepub.com/doi/10.2466/pr0.106.2.448-454', 'Naruhodo#83 – O que são sonhos?https://www.youtube.com/watch?v=rKvDGxCg7XE', 'Naruhodo#156 – O que é paralisia do sono?https://www.youtube.com/watch?v=h9om8soj_uA', 'Naruhodo#123 – O que é e como funciona o sonho lúcido?https://www.youtube.com/watch?v=ThUlmkFFr1U', 'Naruhodo#164 – Podemos ler emoções com base em expressões faciais?https://www.youtube.com/watch?v=cq4oeBZ5kgo', 'Naruhodo#407 – Existe razão sem emoção?https://www.youtube.com/watch?v=qUxluRrHV3E', 'Naruhodo#348 – Sentir medo e ansiedade é algo ruim?https://www.youtube.com/watch?v=u30dN7ACvE4', 'Naruhodo#281 – Aprendemos mais quando somos punidos?https://www.youtube.com/watch?v=hy-SRTS9pW0']

# %%
import time
import csv

SEARCH_URL = 'https://www.b9.com.br/?s=naruhodo&pagina={}'

def get_podcast_posts(page_number):
    soup = get_soup(SEARCH_URL.format(page_number))
    return [a['href'] for a in soup.select('a.c-post-card__link')]

def scrape_references():
    all_references = []
    for page in range(1,18):  # Loop through all pages
        print(f'Scraping page {page}...')
        post_links = get_podcast_posts(page)
        for post_link in post_links:
            print(f'Scraping post {post_link}...')
            references = extract_references(post_link)
            all_references.append([post_link] + references)
            time.sleep(1) 
    return all_references

def save_to_csv(data, filename='references.csv'):
    with open(filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        for row in data:
            writer.writerow(row)

if __name__ == "__main__":
    references = scrape_references()
    save_to_csv(references)
    print("Data has been saved to references.csv")
# Out:
# Scraping page 1...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-418-o-que-e-a-birra/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-417-por-que-respondemos-desastres-com-altruismo/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-415-subir-escadas-pode-ajudar-pessoas-com-transtornos-psiquiatricos/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-414-a-educacao-cientifica-salvara-o-mundo/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-413-como-sabemos-se-uma-coisa-e-causa-de-outra/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-412-por-que-traimos-parte-2-de-2/?highlight=naruhodo...
# Scraping page 2...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-404-por-que-algumas-pessoas-gostam-de-terminar-as-coisas-e-outras-nao/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-403-por-que-temos-fetiches-sexuais/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-402-premio-ignobel-2023-parte-2-de-2/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-401-premio-ignobel-2023-parte-1-de-2/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-entrevista-02-marcelo-batista-nery/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-entrevista-01-nina-da-hora/?highlight=naruhodo...
# Scraping page 3...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-394-a-psicologia-positiva-tem-validade-cientifica-parte-2-de-2/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-393-a-psicologia-positiva-tem-validade-cientifica-parte-1-de-2/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-392-sentimos-atracao-por-pessoas-parecidas-com-a-gente/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-391-por-que-sentimos-inveja/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-390-fazer-compras-para-si-mesma-melhora-o-humor/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-389-por-que-repetir-palavras-deixa-elas-estranhas/?highlight=naruhodo...
# Scraping page 4...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-382-quem-ama-o-feio-bonito-lhe-parece/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-381-por-que-temos-animais-domesticos-parte-2-de-2/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-380-por-que-temos-animais-domesticos-parte-1-de-2/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-379-como-nos-nos-tornamos-nos/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-378-por-que-avisos-de-perigo-nao-sao-seguidos/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-377-aprendemos-melhor-fazendo-pausas/?highlight=naruhodo...
# Scraping page 5...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-370-homens-que-acham-seu-penis-pequeno-gostam-mais-de-carros-esportivos/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-369-e-mais-dificil-fazer-amigos-quando-envelhecemos/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-367-estamos-ficando-mais-esquecidos-do-que-ja-fomos/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-365-o-que-e-e-quais-sao-os-impactos-do-pos-covid-parte-2-de-2/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-364-o-que-e-e-quais-sao-os-impactos-do-pos-covid-parte-1-de-2/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo

# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-234-assistir-a-tv-de-perto-causa-miopia/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-231-gemeos-tem-a-mesma-impressao-digital/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-230-por-que-quando-olhamos-para-uma-pessoa-ela-nos-olha-de-volta/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-229-o-medo-aumenta-a-produtividade-no-trabalho/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-228-todos-nos-enxergamos-as-mesmas-cores-parte-2-de-2/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-227-todos-nos-enxergamos-as-mesmas-cores-parte-1-de-2/?highlight=naruhodo...
# Scraping page 16...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-217-por-que-algumas-pessoas-tremem/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-214-por-que-algumas-pessoas-conseguem-cantar-e-outras-nao-parte-2-de-2/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-213-por-que-algumas-pessoas-conseguem-cantar-e-outras-nao-parte-1-de-2/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-212-cachorros-podem-se-comunicar-como-humanos/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-211-o-que-sao-pessoas-superdotadas/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-210-como-funciona-a-gagueira/?highlight=naruhodo...
# Scraping page 17...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-160-a-ciencia-consegue-explicar-tudo-parte-2-de-2/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-159-a-ciencia-consegue-explicar-tudo-parte-1-de-2/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-158-desafio-naruhodo-quem-sera-devorado-pelo-chefe-gelostofo/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-126-desafio-naruhodo-qual-a-resposta-para-o-problema-do-prisioneiro/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-111-desafio-naruhodo-como-voce-resolveria-o-enigma-da-padaria/?highlight=naruhodo...
# Scraping post https://www.b9.com.br/shows/naruhodo/naruhodo-83-o-que-sao-sonhos/?highlight=naruhodo...
# Data has been saved to references.csv

# %%
import pandas as pd

# Read and Process the CSV File
file_path = 'references.csv'
data = pd.read_csv(file_path, header=None)

# Adjust column names to set the first column as 'Episode'
data.columns = [f'Reference_{i}' if i > 1 else 'Episode' for i in range(1, len(data.columns) + 1)]

# Set the first column ('Episode') as the index
data.set_index('Episode', inplace=True)

# Transpose the DataFrame to make episodes as columns
data_transposed = data.transpose()

# Fill empty values with an empty string
data_transposed.fillna(value='', inplace=True)

# Clean the References
def clean_reference(reference):
    if reference:
        parts = reference.split('https://')
        if len(parts) > 1:
            name = parts[0].strip()
            url = 'https://' + parts[1].strip()
            return f"{name}, {url}"
        else:
            return reference
    else:
        return reference

# Apply the function to clean references
data_transposed = data_transposed.applymap(clean_reference)

# Export the cleaned DataFrame to a CSV file
export_path = 'cleaned_references.csv'
data_transposed.to_csv(export_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 5
#       3 # Read and Process the CSV File
#       4 file_path = 'references.csv'
# ----> 5 data = pd.read_csv(file_path, header=None)
#       7 # Adjust column names to set the first column as 'Episode'
#       8 data.columns = [f'Reference_{i}' if i > 1 else 'Episode' for i in range(1, len(data.columns) + 1)]
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'references.csv'

# %%
from neo4j import GraphDatabase
import csv

# Neo4j connection details
uri = "bolt://localhost:7687"
username = "neo4j"
password = "senha123"

# Connect to Neo4j
driver = GraphDatabase.driver(uri, auth=(username, password))

def load_data(filename='references.csv'):
    data = []
    with open(filename, mode='r', encoding='utf-8') as file:
        reader = csv.reader(file)
        for row in reader:
            data.append(row)
    return data

def create_graph(tx, data):
    for row in data:
        episode = row[0]
        references = row[1:]
        
        # Create or merge the episode node
        tx.run("MERGE (e:Episode {url: $episode})", episode=episode)
        
        for ref in references:
            # Create or merge the reference node
            tx.run("MERGE (r:Reference {url: $ref})", ref=ref)
            # Create the relationship
            tx.run("""
                MATCH (e:Episode {url: $episode})
                MATCH (r:Reference {url: $ref})
                MERGE (e)-[:REFERENCES]->(r)
            """, episode=episode, ref=ref)

def main():
    data = load_data()
    with driver.session() as session:
        session.write_transaction(create_graph, data)
    print("Data has been imported into Neo4j")

if __name__ == "__main__":
    main()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_3152\1349924244.py:41: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(create_graph, data)
# Data has been imported into Neo4j
